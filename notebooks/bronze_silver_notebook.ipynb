# %% [markdown]
# ### ============================================================
# ## BRONZE → SILVER TRANSFORMATION PIPELINE
# ### ============================================================
# ### Purpose:
# ###   - Read Bronze Delta table
# ###   - Clean, standardize, type‑cast, impute, validate
# ###   - Add engineered features
# ###   - Write Silver Delta table (UC-managed)
# ### ============================================================

# %%
#Authorization
spark.conf.set(
  "fs.azure.account.key.<container>.blob.core.windows.net",
  "<security key>"
)

# %%
#Read Bronze table
df = spark.table("<custom>.default.project2_bronze")

# %%
#STANDARDIZE COLUMN NAMES
for col_name in df.columns:
    df = df.withColumnRenamed(
        col_name,
        col_name.strip().lower().replace(" ", "_")
    )

# %%
#REMOVE DUPLICATES
df = df.dropDuplicates()

# %%
#TYPE CASTING
from pyspark.sql.functions import col, to_timestamp

df = df.withColumn("temperature", col("temperature").cast("float"))
df = df.withColumn("humidity", col("humidity").cast("float"))
df = df.withColumn("timestamp", to_timestamp("timestamp"))
df = df.withColumn("device_id", col("device_id").cast("string"))
df = df.withColumn("status", col("status").cast("string"))

# %%
#HANDLE MISSING VALUES (NUMERIC + CATEGORICAL)
from pyspark.sql.functions import avg

# numeric imputations
num_cols = ["temperature", "humidity"]
impute_vals = {c: df.select(avg(c)).first()[0] for c in num_cols}
df = df.fillna(impute_vals)

# categorical imputations
cat_cols = ["device_id", "status"]
df = df.fillna({c: "unknown" for c in cat_cols})

# drop rows missing timestamp (key column)
df = df.filter(col("timestamp").isNotNull())

# %%
#NORMALIZE STATUS
from pyspark.sql.functions import lower, trim

df = df.withColumn("status", lower(trim(col("status"))))

# %%
#FILTER INVALID VALUES
df = df.filter(col("humidity") >= 0)

# %%
#FEATURE ENGINEERING
from pyspark.sql.functions import year, month, dayofweek

df = df.withColumn("year", year("timestamp"))
df = df.withColumn("month", month("timestamp"))
df = df.withColumn("weekday", dayofweek("timestamp"))

# %%
#WRITE SILVER TABLE (UC‑MANAGED DELTA)
df.write.format("delta").mode("overwrite").saveAsTable("<custom>.default.project2_silver")

# %%
# %sql
-- ============================================================
-- VALIDATION / INSPECTION
-- Validation only. Not part of pipeline logic.
-- ============================================================

SELECT * FROM uzi.default.project2_silver LIMIT 20;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>device_id</th><th>timestamp</th><th>temperature</th><th>humidity</th><th>status</th><th>hour_of_day</th><th>temperature_f</th><th>year</th><th>month</th><th>weekday</th></tr></thead><tbody><tr><td>dev-01</td><td>2026-01-01T23:53:00Z</td><td>16.86</td><td>45.42</td><td>on</td><td>null</td><td>null</td><td>2026</td><td>1</td><td>5</td></tr><tr><td>dev-02</td><td>2026-01-01T15:26:00Z</td><td>22.43</td><td>48.08</td><td>off</td><td>null</td><td>null</td><td>2026</td><td>1</td><td>5</td></tr><tr><td>dev-02</td><td>2026-01-01T20:43:00Z</td><td>15.58</td><td>75.82</td><td>on</td><td>null</td><td>null</td><td>2026</td><td>1</td><td>5</td></tr><tr><td>dev-03</td><td>2026-01-01T17:37:00Z</td><td>34.06</td><td>53.58</td><td>off</td><td>null</td><td>null</td><td>2026</td><td>1</td><td>5</td></tr><tr><td>dev-03</td><td>2026-01-01T08:32:00Z</td><td>20.31</td><td>76.24</td><td>on</td><td>null</td><td>null</td><td>2026</td><td>1</td><td>5</td></tr><tr><td>dev-01</td><td>2026-01-01T09:20:00Z</td><td>23.29</td><td>50.01</td><td>on</td><td>null</td><td>null</td><td>2026</td><td>1</td><td>5</td></tr><tr><td>dev-01</td><td>2026-01-01T20:06:00Z</td><td>17.83</td><td>63.54</td><td>off</td><td>null</td><td>null</td><td>2026</td><td>1</td><td>5</td></tr><tr><td>dev-03</td><td>2026-01-01T17:43:00Z</td><td>23.81</td><td>29.86</td><td>on</td><td>null</td><td>null</td><td>2026</td><td>1</td><td>5</td></tr><tr><td>dev-03</td><td>2026-01-01T23:18:00Z</td><td>26.47</td><td>77.77</td><td>on</td><td>null</td><td>null</td><td>2026</td><td>1</td><td>5</td></tr><tr><td>dev-02</td><td>2026-01-01T09:17:00Z</td><td>19.19</td><td>30.0</td><td>off</td><td>null</td><td>null</td><td>2026</td><td>1</td><td>5</td></tr><tr><td>dev-02</td><td>2026-01-01T13:40:00Z</td><td>15.56</td><td>53.24</td><td>error</td><td>null</td><td>null</td><td>2026</td><td>1</td><td>5</td></tr><tr><td>dev-01</td><td>2026-01-01T19:18:00Z</td><td>17.37</td><td>42.5</td><td>off</td><td>null</td><td>null</td><td>2026</td><td>1</td><td>5</td></tr><tr><td>dev-03</td><td>2026-01-01T09:05:00Z</td><td>22.32</td><td>27.23</td><td>err</td><td>null</td><td>null</td><td>2026</td><td>1</td><td>5</td></tr><tr><td>dev-01</td><td>2026-01-01T00:38:00Z</td><td>30.05</td><td>58.75</td><td>err</td><td>null</td><td>null</td><td>2026</td><td>1</td><td>5</td></tr><tr><td>dev-02</td><td>2026-01-01T01:39:00Z</td><td>15.08</td><td>61.75</td><td>off</td><td>null</td><td>null</td><td>2026</td><td>1</td><td>5</td></tr><tr><td>dev-01</td><td>2026-01-01T11:03:00Z</td><td>31.62</td><td>49.54</td><td>err</td><td>null</td><td>null</td><td>2026</td><td>1</td><td>5</td></tr><tr><td>dev-01</td><td>2026-01-01T19:04:00Z</td><td>-999.0</td><td>21.85</td><td>off</td><td>null</td><td>null</td><td>2026</td><td>1</td><td>5</td></tr><tr><td>dev-03</td><td>2026-01-01T15:10:00Z</td><td>32.87</td><td>50.72</td><td>err</td><td>null</td><td>null</td><td>2026</td><td>1</td><td>5</td></tr><tr><td>dev-01</td><td>2026-01-01T01:06:00Z</td><td>21.44</td><td>70.15</td><td>off</td><td>null</td><td>null</td><td>2026</td><td>1</td><td>5</td></tr><tr><td>dev-02</td><td>2026-01-01T16:54:00Z</td><td>20.68</td><td>37.69</td><td>on</td><td>null</td><td>null</td><td>2026</td><td>1</td><td>5</td></tr></tbody></table></div>
